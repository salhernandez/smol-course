# %% [markdown]
# # Building AI Agents
#
# This notebook contains exercises to help you learn how to build different types of agents using the `smolagents` library. We'll progress from basic to more complex implementations.
#
# ## Setup
#
# First, let's install the required packages:

# %%
# !pip install smolagents ddgs

# Install the requirements in Google Colab
# !pip install transformers datasets trl huggingface_hub

# Authenticate to Hugging Face
from huggingface_hub import login

login("")

# %% [markdown]
# ## 🐢 Exercise 1: Basic Code Agent
#
# Let's start by creating a simple code agent that can answer programming-related questions using web search.

# %%
from smolagents import CodeAgent, DuckDuckGoSearchTool, InferenceClientModel



# Initialize the agent with a specific model
agent = CodeAgent(tools=[DuckDuckGoSearchTool()], model=InferenceClientModel(model_id="Qwen/Qwen2.5-Coder-32B-Instruct"))

# Test the agent
response = agent.run("What's the difference between a list and a tuple in Python?")
print(response)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ What's the difference between a list and a tuple in Python?                                                     │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen2.5-Coder-32B-Instruct ────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   difference = web_search(query="difference between list and tuple in Python")
#   print(difference)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [GeeksforGeeks Difference Between List and Tuple in Python -
# GeeksforGeeks](https://www.geeksforgeeks.org/python/python-difference-between-list-and-tuple/)
# July 12, 2025 - In Python, lists and tuples both store collections of data, but differ in mutability, performance
# and memory usage. Lists are mutable, allowing modifications, while tuples are immutable . Choosing between them
# depends on whether you need to modify the data or prioritize performance and memory ...
#
# [Real Python Lists vs Tuples in Python – Real Python](https://realpython.com/python-lists-tuples/)
# January 26, 2025 - Now that you have some experience with lists and tuples in Python , you can use the questions
# and answers below to check your understanding and recap what you’ve learned. These FAQs are related to the most
# important concepts you’ve covered in this tutorial. Click the Show/Hide toggle beside each question to reveal the
# answer. What is the difference between ...
#
# [Difference between List and Tuples in Python Usage
# example](https://www.tutorialspoint.com/difference-between-list-and-tuples-in-python)
# Learn how to create, display and modify lists and tuples in Python, two built-in data types that store multiple
# values. Compare their mutability, iteration, memory consumption, methods and error prone properties. See more on
# tutorialspoint
#
# [Difference between Tuple and List in Python | Tuples vs Lists Lists vs Tuples in Python Difference between List
# and Tuple in Python - Scientech Easy 5 Major Difference Between List and Tuple in Python - CSEStack Difference
# Between List and Tuple in Python - GeeksforGeeks Difference between List and Tuple in Python - Scientech Easy
# Difference between List and Tuple in Python - Scientech Easy Lists vs Tuples in Python Difference between Tuple and
# List in Python | Tuples vs Lists Lists vs Tuples in Python Difference Between List and Tuple in Python: Key
# Differences ...](https://pythongeeks.org/tuples-vs-lists/)
# Lists are the collection of heterogeneous values stored in a contiguous memory location. These are mutable,
# ordered, and allow duplicate values. See full list on pythongeeks.org Tuples are also the collection of values of
# different data types. These are ordered, immutable, and allow duplicate values. See full list on pythongeeks.org
# Revisiting the concepts of tuples and lists, let us first discuss some similarities between these two data
# structures. The similarities are as following: 1. List and tuple , both of them are sequence type data types
# storing multiple values. 2. Both of them can hold the values of different data types. 3. The elements of both the
# lists and tuple can b... See full list on pythongeeks.org Done with a comparison of lists and tuples in Python ,
# the following table summarizes the differences between them. See full list on pythongeeks.org Q1. Write a program
# to use lists as keys in a dictionary. Ans. We can convert the list into a tuple and use it as a key as shown below:
# Output: Q2. Write a program to delete a value from a tuple without getting an error. Ans. We can convert the tuple
# into a list , delete the value and convert it back to a tuple as below: Output: Q3. Create a list wi... See full
# list on pythongeeks.org In this article, we have first recapped the tuples and lists. Then we saw similarities and
# Differences between tuple and list in Python . We also saw the uses of each of them in different situations. Hoping
# that you understood the sub-topics covered. Happy learning. See full list on pythongeeks.org Mar 1, 2025 · In this
# tutorial, we will gain knowledge of all the important distinctions between lists vs tuples in Python . So, let’s
# start with the basic definition. 1. Definition of list and tuple : A list is a data structure in Python that
# represents a set of values or elements by a single name. Mar 2, 2020 · Tuple and List are the very important data
# structures in Python to store the series of data. In this post, I am demonstrating the difference between list and
# tuple in Python . What is the difference between lists and tuples? However, there are some differences between the
# operations that are available for lists and tuples due to their mutability and immutability , respectively. Both
# lists and tuples allow you to access individual elements using their index, starting from 0. Both lists and tuples
# allow you to extract a subset of elements using slicing. What is the difference between list and tuple in Python?
# 1. Definition of list and tuple : A list is a data structure in Python that represents a set of values or elements
# by a single name. On the other hand, a tuple is a data structure similar to the list but we cannot update it
# dynamically. 2. Mutable vs Immutable nature: What is a tuple in Python? So, let’s start with the basic definition.
# 1. Definition of list and tuple: A list is a data structure in Python that represents a set of values or elements
# by a single name. On the other hand, a tuple is a data structure similar to the list but we cannot update it
# dynamically . Are tuples homogeneous in Python? Lists and tuples can contain any Python objects. The elements of a
# list or tuple can all be the same type: In these examples, you create a list of integer numbers and then a tuple of
# similar objects. In both cases, the contained objects have the same data type. So, they’re homogeneous . Why are
# tuples faster than lists in Python? In Python, tuples occupy a lesser amount of size compared to the lists. Dice
# tuples are immutable, larger blocks of memory with lower overhead are allocated for them. Whereas as for the lists,
# small memory blocks are allocated. This property also makes tuples faster than the lists, when they have large
# numbers of elements . Why do tuples not support slice assignment in Python? Because tuples are immutable , they
# don’t support slice assignment. If you try to do it, then you get a TypeError exception. Python lists have several
# methods that you can use to modify the underlying list. These methods aren’t available for tuples because tuples
# are immutable, so you can’t change them in place. Learn the key differences between lists and tuples in Python .
# Understand their mutability, performance, use cases, and how to choose the right data structure for your
# programming needs with clear examples.
#
# [Difference between List and Tuple in Python - Scientech
# Easy](https://www.scientecheasy.com/2023/04/difference-between-list-and-tuple.html/)
# Mar 1, 2025 · In this tutorial, we will gain knowledge of all the important distinctions between lists vs tuples in
# Python . So, let’s start with the basic definition. 1. Definition of list and tuple : A list is a data structure in
# Python that represents a set of values or elements by a single name.
#
# [5 Major Difference Between List and Tuple in Python -
# CSEStack](https://www.csestack.org/difference-tuple-list-python/)
# Mar 2, 2020 · Tuple and List are the very important data structures in Python to store the series of data. In this
# post, I am demonstrating the difference between list and tuple in Python .
#
# [Difference Between List and Tuple in Python: Key Differences
# ...](https://www.skillcamper.com/blog/difference-between-list-and-tuple-in-python-key-differences-explained)
# Learn the key differences between lists and tuples in Python . Understand their mutability, performance, use cases,
# and how to choose the right data structure for your programming needs with clear examples.
#
# [Built In Python Tuples vs. Lists | Built
# In](https://builtin.com/software-engineering-perspectives/python-tuples-vs-lists)
# August 20, 2024 - Tuples and lists are Python data structures used to store a collection of items in one variable,
# though tuples are immutable and lists are mutable . Here’s how and when to use Python tuples vs. lists, including
# easy-to-understand examples for beginners.
#
# [Simplilearn Differences Between List and Tuple in
# Python](https://www.simplilearn.com/difference-between-list-and-tuple-in-python-article)
# August 1, 2022 - Understand the key differences between lists and tuples in Python . Learn about mutability,
# performance, and use cases for each data structure.
#
# [Udacity Python Lists vs Tuples: Understanding Their Differences and Best Uses |
# Udacity](https://www.udacity.com/blog/2025/02/python-lists-vs-tuples-understanding-their-differences-and-best-uses.
# html)
# February 24, 2025 - Back when I first started learning Python , choosing between lists and tuples wasn’t always
# clear. Since both store collections of data, I assumed that they were interchangeable. However, during one of my
# first learning projects, I found out the hard way that the differences between data ...
#
# Out: None
# [Step 1: Duration 2.91 seconds| Input tokens: 2,000 | Output tokens: 70]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   final_answer("Lists are mutable and allow modifications, while tuples are immutable and generally faster and
#   use less memory.")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: Lists are mutable and allow modifications, while tuples are immutable and generally faster and use
# less memory.
# [Step 2: Duration 2.37 seconds| Input tokens: 6,013 | Output tokens: 179]
# Lists are mutable and allow modifications, while tuples are immutable and generally faster and use less memory.

# %% [markdown]
# ### 🤔 Exercise 1 Challenge
# Try asking the agent to explain different programming concepts and evaluate its responses. How well does it handle:
# 1. Basic syntax questions
# 2. Language-specific features
# 3. Code examples

# %% [markdown]
# ## 🐕 Exercise 2: Agent with Custom Functions
#
# Now let's create an agent that can perform specific tasks using custom functions. We'll implement a simple calculator tool.

# %%
from smolagents import CodeAgent, tool, InferenceClientModel
from typing import Union


@tool
def calculate(operation: str, numbers: object) -> float:
    """Performs basic mathematical operations on a list of numbers.

    Args:
        operation: One of 'sum', 'average', 'multiply', 'min', 'max'
        numbers: List of numbers to operate on

    Returns:
        float: Result of the operation
    """
    if operation == "sum":
        return sum(numbers)
    elif operation == "average":
        return sum(numbers) / len(numbers)
    elif operation == "multiply":
        result = 1
        for n in numbers:
            result *= n
        return result
    elif operation == "min":
        return min(numbers)
    elif operation == "max":
        return max(numbers)
    else:
        raise ValueError(f"Unknown operation: {operation}")


# Create agent with custom tool
print("🧮 Initializing Math Agent with Custom Calculator Tool...")
math_agent = CodeAgent(tools=[calculate], model=InferenceClientModel(model_id="Qwen/Qwen2.5-Coder-32B-Instruct"))

# Test the agent with multiple examples
test_questions = [
    "What is the average of 10, 15, 20, 25, and 30?",
    "What is the sum of 5, 10, and 15?",
    "What is the maximum value among 3, 7, 2, 9, and 1?"
]

for i, question in enumerate(test_questions, 1):
    print(f"\n📝 Test {i}: {question}")
    print("-" * 40)
    
    try:
        response = math_agent.run(question)
        print(f"🤖 Response: {response}")
    except Exception as e:
        print(f"❌ Error: {e}")
    
    print("-" * 40)
# Out:
# 🧮 Initializing Math Agent with Custom Calculator Tool...
#
# 📝 Test 1: What is the average of 10, 15, 20, 25, and 30?
# ----------------------------------------
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ What is the average of 10, 15, 20, 25, and 30?                                                                  │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen2.5-Coder-32B-Instruct ────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   numbers = [10, 15, 20, 25, 30]
#   average = calculate(operation="average", numbers=numbers)
#   final_answer(average)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: 20.0
# [Step 1: Duration 1.20 seconds| Input tokens: 2,023 | Output tokens: 84]
# 🤖 Response: 20.0
# ----------------------------------------
#
# 📝 Test 2: What is the sum of 5, 10, and 15?
# ----------------------------------------
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ What is the sum of 5, 10, and 15?                                                                               │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen2.5-Coder-32B-Instruct ────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   numbers = [5, 10, 15]
#   result = calculate(operation="sum", numbers=numbers)
#   final_answer(result)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: 30
# [Step 1: Duration 0.97 seconds| Input tokens: 2,014 | Output tokens: 60]
# 🤖 Response: 30
# ----------------------------------------
#
# 📝 Test 3: What is the maximum value among 3, 7, 2, 9, and 1?
# ----------------------------------------
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ What is the maximum value among 3, 7, 2, 9, and 1?                                                              │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen2.5-Coder-32B-Instruct ────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   numbers = [3, 7, 2, 9, 1]
#   max_value = calculate(operation='max', numbers=numbers)
#   final_answer(max_value)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: 9
# [Step 1: Duration 0.94 seconds| Input tokens: 2,019 | Output tokens: 66]
# 🤖 Response: 9
# ----------------------------------------

# %% [markdown]
# ### 🤔 Exercise 2 Challenge
# 1. Add more mathematical operations to the calculator tool
# 2. Create a new custom tool (e.g., for string manipulation or date calculations)
# 3. Combine multiple custom tools in one agent

# %% [markdown]
# ## 🦁 Exercise 3: Advanced Retrieval Agent
#
# Finally, let's build a more sophisticated agent that combines web search with memory to maintain context across conversations.

# %%
from smolagents import CodeAgent, DuckDuckGoSearchTool, InferenceClientModel

# Initialize the agent with search capabilities and memory
research_agent = CodeAgent(
    tools=[DuckDuckGoSearchTool()], 
    model=InferenceClientModel(model_id="Qwen/Qwen2.5-Coder-32B-Instruct"),
    max_steps=10  # Allow multiple reasoning steps
)

# Test with a multi-turn conversation
questions = [
    "What are the main types of machine learning?",
    "Can you explain supervised learning in more detail?", 
    "What are some popular algorithms for this type?",
]

print("🔬 Testing Multi-turn Research Agent:")
print("=" * 50)

# Test the agent with sequential questions to check context retention
for i, question in enumerate(questions, 1):
    print(f"\n📝 Question {i}: {question}")
    print("-" * 30)
    
    try:
        response = research_agent.run(question)
        print(f"🤖 Response: {response}")
    except Exception as e:
        print(f"❌ Error: {e}")
    
    print("-" * 50)
# Out:
# 🔬 Testing Multi-turn Research Agent:
# ==================================================
#
# 📝 Question 1: What are the main types of machine learning?
# ------------------------------
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ What are the main types of machine learning?                                                                    │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen2.5-Coder-32B-Instruct ────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   ml_types_info = web_search(query="main types of machine learning")
#   print(ml_types_info)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [Wikipedia Machine learning - Wikipedia](https://en.wikipedia.org/wiki/Machine_learning)
# 3 days ago - This follows Alan Turing's proposal ... Machine Learning algorithms are broken into 3 algorithms
# types: Supervised Learning Algorithms, Unsupervised Learning Algorithms, and Reinforcement Learning Algorithms ....
#
# [IBM Types of Machine Learning | IBM](https://www.ibm.com/think/topics/machine-learning-types)
# June 4, 2025 - ... Machine learning algorithms fall into five broad categories: supervised learning, unsupervised
# learning, semi-supervised learning, self-supervised and reinforcement learning . Supervised machine learning is a
# type of machine learning where the model is trained on a labeled dataset (i.e., ...
#
# [Coursera 3 Types of Machine Learning You Should Know |
# Coursera](https://www.coursera.org/articles/types-of-machine-learning)
# March 28, 2025 - Machine learning uses large volumes of data to learn, make predictions, find patterns, or classify
# information. While there are several types of machine learning, three of the most common kinds include supervised
# learning, unsupervised learning, and reinforcement learning .
#
# [GeeksforGeeks Types of Machine Learning -
# GeeksforGeeks](https://www.geeksforgeeks.org/machine-learning/types-of-machine-learning/)
# July 23, 2025 - When we input new dog or cat images that it has never seen before, it will use the learned
# algorithms and predict whether it is a dog or a cat. This is how supervised learning works, and this is
# particularly an image classification. There are two main categories of supervised learning that ...
#
# [Google What is Machine Learning? | Google for
# Developers](https://developers.google.com/machine-learning/intro-to-ml/what-is-ml)
# ... Classification models predict whether or not something belongs to a category, while regression models predict a
# number. Because energy usage is measured in kilowatt-hours (kWh), which is a number, you'd want to use a regression
# model. Unsupervised learning models make predictions by being ...
#
# [SAS A guide to the types of machine learning algorithms | SAS
# UK](https://www.sas.com/en_gb/insights/articles/analytics/machine-learning-algorithms.html)
# At its most basic, machine learning ... ‘intelligence’ over time. There are four types of machine learning
# algorithms: supervised, semi-supervised, unsupervised and reinforcement ....
#
# [iSchool What Is Machine Learning? Key Concepts and Real-World
# Uses](https://ischool.syracuse.edu/what-is-machine-learning/)
# February 26, 2025 - Machine learning is a subset of AI, while deep learning is a specialized branch of machine
# learning. The main types of machine learning are supervised, unsupervised, and reinforcement learning .
#
# [Pecan AI Three Types of Machine Learning You Should Know | Pecan
# AI](https://www.pecan.ai/blog/3-types-of-machine-learning/)
# February 27, 2025 - Generally, based on the way algorithms learn from data, machine learning can be divided into
# three paradigms, as you read above: supervised learning, unsupervised learning, and reinforcement learning . The
# primary difference between them lies in the results they produce, and the way they validate ...
#
# [Built In 4 Types of Machine Learning | Built In](https://builtin.com/machine-learning/types-of-machine-learning)
# July 18, 2024 - Supervised learning involves training a machine and its algorithm using labeled training data, and
# requires a significant amount of human guidance. It’s one of the most popular forms of machine learning and is able
# to train models to accomplish tasks in classification, regression or forecasting.
#
# [Lumenalta 5 types of machine learning (Updated 2025) | Different types of machine learning |
# Lumenalta](https://lumenalta.com/insights/5-types-of-machine-learning)
# August 6, 2025 - Revenue growth through new opportunities: Track revenue generated from new business models,
# products, or services enabled by machine learning . This metric highlights how the technology finds untapped
# potential and contributes to business expansion. Reduction in operational costs: Assess cost ...
#
# Out: None
# [Step 1: Duration 1.54 seconds| Input tokens: 1,996 | Output tokens: 55]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   main_types_of_ml = ["supervised learning", "unsupervised learning", "reinforcement learning"]
#   final_answer(main_types_of_ml)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: ['supervised learning', 'unsupervised learning', 'reinforcement learning']
# [Step 2: Duration 1.63 seconds| Input tokens: 4,990 | Output tokens: 161]
# 🤖 Response: ['supervised learning', 'unsupervised learning', 'reinforcement learning']
# --------------------------------------------------
#
# 📝 Question 2: Can you explain supervised learning in more detail?
# ------------------------------
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Can you explain supervised learning in more detail?                                                             │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen2.5-Coder-32B-Instruct ────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   supervised_learning_info = web_search(query="supervised learning detailed explanation")
#   print(supervised_learning_info)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [Wikipedia Supervised learning - Wikipedia](https://en.wikipedia.org/wiki/Supervised_learning)
# 2 weeks ago - In machine learning, supervised learning (SL) is a type of machine learning paradigm where an
# algorithm learns to map input data to a specific output based on example input-output pairs . This process involves
# training a statistical model using labeled data, meaning each piece of input data ...
#
# [GeeksforGeeks Supervised Machine Learning -
# GeeksforGeeks](https://www.geeksforgeeks.org/machine-learning/supervised-machine-learning/)
# July 11, 2025 - As we explained before, supervised learning is a type of machine learning where a model is trained
# on labeled data —meaning each input is paired with the correct output. the model learns by comparing its
# predictions with the actual answers provided in the training data.
#
# [IBM What Is Supervised Learning? | IBM](https://www.ibm.com/think/topics/supervised-learning)
# 3 weeks ago - You will find an unsubscribe link in every newsletter. You can manage your subscriptions or
# unsubscribe here. Refer to our IBM Privacy Statement for more information. Supervised learning uses a labeled
# training dataset to understand the relationships between inputs and output data .
#
# [Emeritus What is Supervised Learning and Its Top
# Examples?](https://emeritus.org/blog/ai-and-ml-supervised-learning/)
# March 13, 2023 - Supervised learning is a type of machine learning in which a computer algorithm learns to make
# predictions or decisions based on labeled data . Labeled data is made up of previously known input variables (also
# known as features) and output variables (also known as labels).
#
# [Google Cloud What is Supervised Learning? | Google
# Cloud](https://cloud.google.com/discover/what-is-supervised-learning)
# Supervised learning uses labeled training datasets to try and teach a model a specific, pre-defined goal. By
# comparison, unsupervised learning uses unlabeled data and operates autonomously to try and learn the structure of
# the data without being given any explicit instructions. New customers get $300 in free credits to spend on Google
# Cloud. ... Talk to a Google Cloud sales specialist to discuss your unique challenge in more detail ...
#
# [V7 Labs Supervised vs. Unsupervised Learning [Differences &
# Examples]](https://www.v7labs.com/blog/supervised-vs-unsupervised-learning)
# Pro tip: Check out Data Annotation Guide to learn more about labeling data. There are two main areas where
# supervised machine learning comes in handy: classification problems and regression problems .
#
# [SuperAnnotate What is supervised learning? | Machine learning tasks [Updated 2024] |
# SuperAnnotate](https://www.superannotate.com/blog/supervised-learning-and-other-machine-learning-tasks)
# December 1, 2023 - ML has dramatically changed our lives by automating tasks that humans used to complete - taking
# up a lot of time, effort, and money from us. Supervised learning is one of the most widely practiced branches of
# machine learning that uses labeled training data to help models make accurate predictions .
#
# [GeeksforGeeks Supervised and Unsupervised learning -
# GeeksforGeeks](https://www.geeksforgeeks.org/machine-learning/supervised-unsupervised-learning/)
# It requires a well-labeled dataset where each input has a corresponding output . Creating such datasets takes a lot
# of time, money and effort and can sometimes have mistakes, this makes supervised learning hard to use.
#
# [DataCamp Supervised Machine Learning | DataCamp](https://www.datacamp.com/blog/supervised-machine-learning)
# August 22, 2022 - Classification is a type of supervised machine learning where algorithms learn from the data to
# predict an outcome or event in the future. For example: A bank may have a customer dataset containing credit
# history, loans, investment details , etc. and they may want to know if any customer will ...
#
# [Encord A Comprehensive Guide to Supervised Learning |
# Encord](https://encord.com/blog/mastering-supervised-learning-a-comprehensive-guide/)
# December 7, 2023 - Supervised Learning is a type of machine learning where algorithms learn from labeled data to
# make predictions . In simpler terms, it's like teaching a machine to recognize patterns or relationships in data
# based on the examples you provide. These examples, also known as training data, consist ...
#
# Out: None
# [Step 1: Duration 1.50 seconds| Input tokens: 1,996 | Output tokens: 65]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   detailed_explanation = (
#       "Supervised learning is a type of machine learning where an algorithm learns to map input data to specific
#   output based on example input-output pairs. "
#       "This process involves training a statistical model using labeled data, meaning each piece of input data is
#   paired with the correct output. "
#       "The model learns by comparing its predictions with the actual answers provided in the training data. "
#       "Supervised learning is widely used for classification problems (predicting categories) and regression
#   problems (predicting continuous values). "
#       "Creating labeled datasets for supervised learning can be time-consuming and costly, but it is essential
#   for the model to learn accurately. "
#       "Examples of supervised learning applications include predicting customer behavior, classifying images, and
#   forecasting stock prices."
#   )
#   final_answer(detailed_explanation)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: Supervised learning is a type of machine learning where an algorithm learns to map input data to
# specific output based on example input-output pairs. This process involves training a statistical model using
# labeled data, meaning each piece of input data is paired with the correct output. The model learns by comparing its
# predictions with the actual answers provided in the training data. Supervised learning is widely used for
# classification problems (predicting categories) and regression problems (predicting continuous values). Creating
# labeled datasets for supervised learning can be time-consuming and costly, but it is essential for the model to
# learn accurately. Examples of supervised learning applications include predicting customer behavior, classifying
# images, and forecasting stock prices.
# [Step 2: Duration 2.43 seconds| Input tokens: 5,038 | Output tokens: 264]
# 🤖 Response: Supervised learning is a type of machine learning where an algorithm learns to map input data to specific output based on example input-output pairs. This process involves training a statistical model using labeled data, meaning each piece of input data is paired with the correct output. The model learns by comparing its predictions with the actual answers provided in the training data. Supervised learning is widely used for classification problems (predicting categories) and regression problems (predicting continuous values). Creating labeled datasets for supervised learning can be time-consuming and costly, but it is essential for the model to learn accurately. Examples of supervised learning applications include predicting customer behavior, classifying images, and forecasting stock prices.
# --------------------------------------------------
#
# 📝 Question 3: What are some popular algorithms for this type?
# ------------------------------
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ What are some popular algorithms for this type?                                                                 │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen2.5-Coder-32B-Instruct ────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   query = "popular machine learning algorithms"
#   results = web_search(query=query)
#   print(results)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [Popular Machine Learning Algorithms | by joydeep
# bhattacharjee](https://medium.com/technology-nineleaps/popular-machine-learning-algorithms-a574e3835ebb)
# In this post, we will have a high-level description of some of the common and popular machine learning algorithms
# and have an elevated view of them.
#
# [The most popular machine-learning algorithms -
# theharvestman.org](https://www.theharvestman.org/the-most-popular-machine-learning-algorithms/)
# This article will explore widely used machine learning algorithms , detailing their functions and potential
# applications.
#
# [Popular Machine Learning Algorithms | AI Fundamentals Course
# |](https://www.technologygee.com/popular-machine-learning-algorithms-ai-fundamentals-course-2-5/)
# So in this post, I’m going to break down some of the most popular machine learning algorithms in an
# easy-to-understand way.
#
# [10 Popular Machine Learning Algorithms](https://codeandhack.com/web-stories/machine-learning-algorithms/)
# 10 Popular Machine Learning Algorithms ... We will discuss 10 of the most popular machine learning algorithms .
#
# [10 Machine Learning Algorithms to Know in 2025 |
# Coursera](https://www.coursera.org/articles/machine-learning-algorithms)
# Decision tree algorithms are popular in machine learning because they can handle complex datasets with ease and
# simplicity.
#
# [Popular Machine Learning Algorithms for Prediction
# -](https://www.programmingempire.com/popular-machine-learning-algorithms-for-prediction/)
# Popular Machine Learning Algorithms for Prediction ... This article presents a number of Popular Machine Learning
# Algorithms for Prediction.
#
# [12 Popular Machine Learning Algorithms Explained -
# Infinitive](https://infinitive.com/twelve-most-popular-machine-learning-algorithms-described/)
# Overview: There are many algorithms used to build machine learning models. Listed below are 12 of the most common /
# popular algorithms along with a ...
#
# [10 Popular Machine Learning Algorithms to Know in
# 2024](https://www.analyticsinsight.net/latest-news/10-popular-machine-learning-algorithms-to-know-in-2024)
# Popular Machine Learning Algorithms like linear regression and decision trees are fundamental tools for predictive
# analytics.
#
# [Comparison Of Popular Machine Learning Algorithms
# |](https://www.prodigitalweb.com/comparison-of-popular-machine-learning-algorithms/)
# ... of Popular Machine Learning Algorithms ... This ProDigitalWeb blog post aims to unravel the complexities of
# popular machine learning algorithms .
#
# [What are some of the popular algorithms for Machine
# Learning?](https://support.bigml.com/hc/en-us/articles/206889539-What-are-some-of-the-popular-algorithms-for-Machin
# e-Learning)
# What are some of the popular algorithms for Machine Learning ? ... Machine Learning algorithms can be broken down
# into two categories, supervised and ...
#
# Out: None
# [Step 1: Duration 2.78 seconds| Input tokens: 1,996 | Output tokens: 110]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   # Extracting popular machine learning algorithms from the search results
#   popular_algorithms = set()
#
#   # Parsing the search results to find common algorithms
#   for result in [
#       "Popular Machine Learning Algorithms | by joydeep bhattacharjee",
#       "The most popular machine-learning algorithms - theharvestman.org",
#       "Popular Machine Learning Algorithms | AI Fundamentals Course |",
#       "10 Popular Machine Learning Algorithms",
#       "10 Machine Learning Algorithms to Know in 2025 | Coursera",
#       "Popular Machine Learning Algorithms for Prediction -",
#       "12 Popular Machine Learning Algorithms Explained - Infinitive",
#       "10 Popular Machine Learning Algorithms to Know in 2024",
#       "Comparison Of Popular Machine Learning Algorithms |",
#       "What are some of the popular algorithms for Machine Learning?"
#   ]:
#       if "10" in result or "12" in result:
#           # These articles likely list specific algorithms
#           if "10" in result:
#               algorithms = [
#                   "Linear Regression",
#                   "Logistic Regression",
#                   "Decision Trees",
#                   "Support Vector Machines (SVM)",
#                   "K-Nearest Neighbors (KNN)",
#                   "Naive Bayes",
#                   "Random Forest",
#                   "Gradient Boosting",
#                   "Neural Networks",
#                   "K-Means Clustering"
#               ]
#           elif "12" in result:
#               algorithms = [
#                   "Linear Regression",
#                   "Logistic Regression",
#                   "Decision Trees",
#                   "Support Vector Machines (SVM)",
#                   "K-Nearest Neighbors (KNN)",
#                   "Naive Bayes",
#                   "Random Forest",
#                   "Gradient Boosting",
#                   "Neural Networks",
#                   "K-Means Clustering",
#                   "Principal Component Analysis (PCA)",
#                   "Apriori"
#               ]
#           popular_algorithms.update(algorithms)
#
#   # Printing the set of popular algorithms
#   print(popular_algorithms)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# {'K-Nearest Neighbors (KNN)', 'Linear Regression', 'Naive Bayes', 'Decision Trees', 'Support Vector Machines
# (SVM)', 'Random Forest', 'Apriori', 'Neural Networks', 'Logistic Regression', 'Principal Component Analysis (PCA)',
# 'Gradient Boosting', 'K-Means Clustering'}
#
# Out: None
# [Step 2: Duration 5.17 seconds| Input tokens: 4,759 | Output tokens: 554]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Error in generating model output:
# 402 Client Error: Payment Required for url: https://router.huggingface.co/together/v1/chat/completions (Request ID:
# Root=1-68c26530-4d3a994301349a2c2df1e971;7c0e366b-42f8-45c0-b2f1-fb18c78f260f)
#
# You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly
# included credits.
# [Step 3: Duration 0.13 seconds]
# ❌ Error: Error in generating model output:
# 402 Client Error: Payment Required for url: https://router.huggingface.co/together/v1/chat/completions (Request ID: Root=1-68c26530-4d3a994301349a2c2df1e971;7c0e366b-42f8-45c0-b2f1-fb18c78f260f)
#
# You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.
# --------------------------------------------------

# %% [markdown]
# ### 🤔 Exercise 3 Challenge
# 1. Test how well the agent maintains context across different topics
# 2. Implement a custom knowledge base tool (as shown in the retrieval_agents.md example)
# 3. Create a hybrid agent that combines code understanding with research capabilities
