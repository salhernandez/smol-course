# %% [markdown]
# # Generate a dataset for instruction tuning
#
# This notebook will guide you through the process of generating a dataset for instruction tuning. We'll use the `distilabel` package to generate a dataset for instruction tuning.
#
# So let's dig in to some instruction tuning datasets.
#
# <div style='background-color: lightblue; padding: 10px; border-radius: 5px; margin-bottom: 20px; color:black'>
#     <h2 style='margin: 0;color:blue'>Exercise: Generate a dataset for instruction tuning</h2>
#     <p>Now that you've seen how to generate a dataset for instruction tuning, try generating a dataset for instruction tuning.</p>
#     <p><b>Difficulty Levels</b></p>
#     <p>🐢 Generate an instruction tuning dataset</p>
#     <p>🐕 Generate a dataset for instruction tuning with seed data</p>
#     <p>🦁 Generate a dataset for instruction tuning with seed data and with instruction evolution</p>
# </div>

# %% [markdown]
# ## Install dependencies
#
# Instead of transformers, you can also install `vllm` or `hf-inference-endpoints`.

# %%
# !pip install "distilabel[hf-transformers,outlines,instructor]"

# %%
# Login to Hugging Face to access models and push datasets
from huggingface_hub import login

# You can either:
# 1. Pass your token directly: login("your_token_here")
# 2. Use the notebook widget to enter your token interactively
# 3. Set the HF_TOKEN environment variable

login("")

# %% [markdown]
# ## Start synthesizing
#
# As we've seen in the previous course content, we can create a distilabel pipelines for instruction dataset generation. The bare minimum pipline is already provided. Make sure to scale up this pipeline to generate a large dataset for instruction tuning. Swap out models, model providers and generation arguments to see how they affect the quality of the dataset. Experiment small, scale up later.
#
# Check out the [distilabel components gallery](https://distilabel.argilla.io/latest/components-gallery/) for information about the processing classes and how to use them.
#
# An example of loading data from the Hub instead of dictionaries is provided below.
#
# ```python
# from datasets import load_dataset
#
# with Pipeline(...) as pipeline:
#     ...
#
# if __name__ == "__main__:
#     dataset = load_dataset("my-dataset", split="train")
#     distiset = pipeline.run(dataset=dataset)
# ```
#
# Don't forget to push your dataset to the Hub after running the pipeline!

# %%
from distilabel.llms import TransformersLLM
from distilabel.pipeline import Pipeline
from distilabel.steps import LoadDataFromDicts
from distilabel.steps.tasks import TextGeneration

with Pipeline() as pipeline:
    data = LoadDataFromDicts(data=[{"instruction": "Generate a short question about the Hugging Face Smol-Course."}])
    llm = TransformersLLM(model="HuggingFaceTB/SmolLM2-1.7B-Instruct")
    gen_a = TextGeneration(llm=llm, output_mappings={"generation": "instruction"})
    gen_b = TextGeneration(llm=llm, output_mappings={"generation": "response"})
    data >> gen_a >> gen_b

if __name__ == "__main__":
    distiset = pipeline.run(use_cache=False)
    
    # Create the repository if it doesn't exist, then push the dataset
    from huggingface_hub import create_repo, HfApi
    
    repo_name = "huggingface-smol-course-instruction-tuning-dataset"
    
    try:
        # Try to create the repository (will skip if it already exists)
        create_repo(repo_name, repo_type="dataset", exist_ok=True)
        print(f"✅ Repository '{repo_name}' is ready")
    except Exception as e:
        print(f"⚠️ Repository creation note: {e}")
    
    # Push the dataset to the hub
    distiset.push_to_hub(repo_name)
    print(f"🎉 Dataset successfully pushed to: https://huggingface.co/datasets/{repo_name}")
# Out:
# [08/27/25 20:24:59] INFO     ['distilabel.pipeline'] 📝 Pipeline data will be written to               ]8;id=145122;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=410755;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1015\1015]8;;\
#                              '/home/ai-makina/.cache/distilabel/pipelines/pipeline_load_data_from_dict
#                              s_0_text_generation_0_text_generation_1/c01ebfb0c402b5259a883a99a288ac77e
#                              435bd20/executions/ba93fee5474d2e343a10a1c4b6e96bcada7c66a6/data/steps_ou
#                              tputs'
#                     INFO     ['distilabel.pipeline'] ⌛ The steps of the pipeline will be loaded in    ]8;id=97096;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=778306;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1046\1046]8;;\
#                              stages:
#                               * Legend: 🚰 GeneratorStep 🌐 GlobalStep 🔄 Step
#                               * Stage 0:
#                                 - 🚰 'load_data_from_dicts_0'
#                                 - 🔄 'text_generation_0'
#                                 - 🔄 'text_generation_1'
# [08/27/25 20:24:59] INFO     ['distilabel.pipeline'] 📝 Pipeline data will be written to               ]8;id=145122;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=410755;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1015\1015]8;;\
#                              '/home/ai-makina/.cache/distilabel/pipelines/pipeline_load_data_from_dict
#                              s_0_text_generation_0_text_generation_1/c01ebfb0c402b5259a883a99a288ac77e
#                              435bd20/executions/ba93fee5474d2e343a10a1c4b6e96bcada7c66a6/data/steps_ou
#                              tputs'
#                     INFO     ['distilabel.pipeline'] ⌛ The steps of the pipeline will be loaded in    ]8;id=97096;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=778306;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1046\1046]8;;\
#                              stages:
#                               * Legend: 🚰 GeneratorStep 🌐 GlobalStep 🔄 Step
#                               * Stage 0:
#                                 - 🚰 'load_data_from_dicts_0'
#                                 - 🔄 'text_generation_0'
#                                 - 🔄 'text_generation_1'
#                     INFO     ['distilabel.pipeline'] ⏳ Waiting for all the steps of stage 0 to        ]8;id=899499;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=372388;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1382\1382]8;;\
#                              load...
# [08/27/25 20:24:59] INFO     ['distilabel.pipeline'] 📝 Pipeline data will be written to               ]8;id=145122;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=410755;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1015\1015]8;;\
#                              '/home/ai-makina/.cache/distilabel/pipelines/pipeline_load_data_from_dict
#                              s_0_text_generation_0_text_generation_1/c01ebfb0c402b5259a883a99a288ac77e
#                              435bd20/executions/ba93fee5474d2e343a10a1c4b6e96bcada7c66a6/data/steps_ou
#                              tputs'
#                     INFO     ['distilabel.pipeline'] ⌛ The steps of the pipeline will be loaded in    ]8;id=97096;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=778306;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1046\1046]8;;\
#                              stages:
#                               * Legend: 🚰 GeneratorStep 🌐 GlobalStep 🔄 Step
#                               * Stage 0:
#                                 - 🚰 'load_data_from_dicts_0'
#                                 - 🔄 'text_generation_0'
#                                 - 🔄 'text_generation_1'
#                     INFO     ['distilabel.pipeline'] ⏳ Waiting for all the steps of stage 0 to        ]8;id=899499;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=372388;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1382\1382]8;;\
#                              load...
# Device set to use cuda:0
# Device set to use cuda:0
# Device set to use cuda:0
# [08/27/25 20:24:59] INFO     ['distilabel.pipeline'] 📝 Pipeline data will be written to               ]8;id=145122;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=410755;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1015\1015]8;;\
#                              '/home/ai-makina/.cache/distilabel/pipelines/pipeline_load_data_from_dict
#                              s_0_text_generation_0_text_generation_1/c01ebfb0c402b5259a883a99a288ac77e
#                              435bd20/executions/ba93fee5474d2e343a10a1c4b6e96bcada7c66a6/data/steps_ou
#                              tputs'
#                     INFO     ['distilabel.pipeline'] ⌛ The steps of the pipeline will be loaded in    ]8;id=97096;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=778306;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1046\1046]8;;\
#                              stages:
#                               * Legend: 🚰 GeneratorStep 🌐 GlobalStep 🔄 Step
#                               * Stage 0:
#                                 - 🚰 'load_data_from_dicts_0'
#                                 - 🔄 'text_generation_0'
#                                 - 🔄 'text_generation_1'
#                     INFO     ['distilabel.pipeline'] ⏳ Waiting for all the steps of stage 0 to        ]8;id=899499;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=372388;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1382\1382]8;;\
#                              load...
# Device set to use cuda:0
# Device set to use cuda:0
# Device set to use cuda:0
# [08/27/25 20:25:02] INFO     ['distilabel.pipeline'] ⏳ Steps from stage 0 loaded: 1/3                 ]8;id=204654;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=17810;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1418\1418]8;;\
#                               * 'load_data_from_dicts_0' replicas: 1/1
#                               * 'text_generation_0' replicas: 0/1
#                               * 'text_generation_1' replicas: 0/1
# [08/27/25 20:24:59] INFO     ['distilabel.pipeline'] 📝 Pipeline data will be written to               ]8;id=145122;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=410755;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1015\1015]8;;\
#                              '/home/ai-makina/.cache/distilabel/pipelines/pipeline_load_data_from_dict
#                              s_0_text_generation_0_text_generation_1/c01ebfb0c402b5259a883a99a288ac77e
#                              435bd20/executions/ba93fee5474d2e343a10a1c4b6e96bcada7c66a6/data/steps_ou
#                              tputs'
#                     INFO     ['distilabel.pipeline'] ⌛ The steps of the pipeline will be loaded in    ]8;id=97096;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=778306;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1046\1046]8;;\
#                              stages:
#                               * Legend: 🚰 GeneratorStep 🌐 GlobalStep 🔄 Step
#                               * Stage 0:
#                                 - 🚰 'load_data_from_dicts_0'
#                                 - 🔄 'text_generation_0'
#                                 - 🔄 'text_generation_1'
#                     INFO     ['distilabel.pipeline'] ⏳ Waiting for all the steps of stage 0 to        ]8;id=899499;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=372388;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1382\1382]8;;\
#                              load...
# Device set to use cuda:0
# Device set to use cuda:0
# Device set to use cuda:0
# [08/27/25 20:25:02] INFO     ['distilabel.pipeline'] ⏳ Steps from stage 0 loaded: 1/3                 ]8;id=204654;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=17810;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1418\1418]8;;\
#                               * 'load_data_from_dicts_0' replicas: 1/1
#                               * 'text_generation_0' replicas: 0/1
#                               * 'text_generation_1' replicas: 0/1
# [08/27/25 20:25:04] INFO     ['distilabel.pipeline'] ⏳ Steps from stage 0 loaded: 3/3                 ]8;id=555088;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=897276;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1418\1418]8;;\
#                               * 'load_data_from_dicts_0' replicas: 1/1
#                               * 'text_generation_0' replicas: 1/1
#                               * 'text_generation_1' replicas: 1/1
#                     INFO     ['distilabel.pipeline'] ✅ All the steps from stage 0 have been loaded!   ]8;id=822695;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=119394;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1422\1422]8;;\
# [08/27/25 20:24:59] INFO     ['distilabel.pipeline'] 📝 Pipeline data will be written to               ]8;id=145122;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=410755;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1015\1015]8;;\
#                              '/home/ai-makina/.cache/distilabel/pipelines/pipeline_load_data_from_dict
#                              s_0_text_generation_0_text_generation_1/c01ebfb0c402b5259a883a99a288ac77e
#                              435bd20/executions/ba93fee5474d2e343a10a1c4b6e96bcada7c66a6/data/steps_ou
#                              tputs'
#                     INFO     ['distilabel.pipeline'] ⌛ The steps of the pipeline will be loaded in    ]8;id=97096;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=778306;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1046\1046]8;;\
#                              stages:
#                               * Legend: 🚰 GeneratorStep 🌐 GlobalStep 🔄 Step
#                               * Stage 0:
#                                 - 🚰 'load_data_from_dicts_0'
#                                 - 🔄 'text_generation_0'
#                                 - 🔄 'text_generation_1'
#                     INFO     ['distilabel.pipeline'] ⏳ Waiting for all the steps of stage 0 to        ]8;id=899499;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=372388;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1382\1382]8;;\
#                              load...
# Device set to use cuda:0
# Device set to use cuda:0
# Device set to use cuda:0
# [08/27/25 20:25:02] INFO     ['distilabel.pipeline'] ⏳ Steps from stage 0 loaded: 1/3                 ]8;id=204654;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=17810;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1418\1418]8;;\
#                               * 'load_data_from_dicts_0' replicas: 1/1
#                               * 'text_generation_0' replicas: 0/1
#                               * 'text_generation_1' replicas: 0/1
# [08/27/25 20:25:04] INFO     ['distilabel.pipeline'] ⏳ Steps from stage 0 loaded: 3/3                 ]8;id=555088;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=897276;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1418\1418]8;;\
#                               * 'load_data_from_dicts_0' replicas: 1/1
#                               * 'text_generation_0' replicas: 1/1
#                               * 'text_generation_1' replicas: 1/1
#                     INFO     ['distilabel.pipeline'] ✅ All the steps from stage 0 have been loaded!   ]8;id=822695;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=119394;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1422\1422]8;;\
#                     INFO     ['distilabel.step.load_data_from_dicts_0'] 🚰 Starting yielding    ]8;id=344774;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=116095;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/step_wrapper.py#179\179]8;;\
#                              batches from generator step 'load_data_from_dicts_0'. Offset: 0
# [08/27/25 20:24:59] INFO     ['distilabel.pipeline'] 📝 Pipeline data will be written to               ]8;id=145122;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=410755;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1015\1015]8;;\
#                              '/home/ai-makina/.cache/distilabel/pipelines/pipeline_load_data_from_dict
#                              s_0_text_generation_0_text_generation_1/c01ebfb0c402b5259a883a99a288ac77e
#                              435bd20/executions/ba93fee5474d2e343a10a1c4b6e96bcada7c66a6/data/steps_ou
#                              tputs'
#                     INFO     ['distilabel.pipeline'] ⌛ The steps of the pipeline will be loaded in    ]8;id=97096;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=778306;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1046\1046]8;;\
#                              stages:
#                               * Legend: 🚰 GeneratorStep 🌐 GlobalStep 🔄 Step
#                               * Stage 0:
#                                 - 🚰 'load_data_from_dicts_0'
#                                 - 🔄 'text_generation_0'
#                                 - 🔄 'text_generation_1'
#                     INFO     ['distilabel.pipeline'] ⏳ Waiting for all the steps of stage 0 to        ]8;id=899499;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=372388;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1382\1382]8;;\
#                              load...
# Device set to use cuda:0
# Device set to use cuda:0
# Device set to use cuda:0
# [08/27/25 20:25:02] INFO     ['distilabel.pipeline'] ⏳ Steps from stage 0 loaded: 1/3                 ]8;id=204654;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=17810;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1418\1418]8;;\
#                               * 'load_data_from_dicts_0' replicas: 1/1
#                               * 'text_generation_0' replicas: 0/1
#                               * 'text_generation_1' replicas: 0/1
# [08/27/25 20:25:04] INFO     ['distilabel.pipeline'] ⏳ Steps from stage 0 loaded: 3/3                 ]8;id=555088;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=897276;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1418\1418]8;;\
#                               * 'load_data_from_dicts_0' replicas: 1/1
#                               * 'text_generation_0' replicas: 1/1
#                               * 'text_generation_1' replicas: 1/1
#                     INFO     ['distilabel.pipeline'] ✅ All the steps from stage 0 have been loaded!   ]8;id=822695;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=119394;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1422\1422]8;;\
#                     INFO     ['distilabel.step.load_data_from_dicts_0'] 🚰 Starting yielding    ]8;id=344774;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=116095;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/step_wrapper.py#179\179]8;;\
#                              batches from generator step 'load_data_from_dicts_0'. Offset: 0
#                     INFO     ['distilabel.step.load_data_from_dicts_0'] 📨 Step                 ]8;id=812359;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=287421;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/step_wrapper.py#290\290]8;;\
#                              'load_data_from_dicts_0' sending batch 0 to output queue
# [08/27/25 20:24:59] INFO     ['distilabel.pipeline'] 📝 Pipeline data will be written to               ]8;id=145122;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=410755;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1015\1015]8;;\
#                              '/home/ai-makina/.cache/distilabel/pipelines/pipeline_load_data_from_dict
#                              s_0_text_generation_0_text_generation_1/c01ebfb0c402b5259a883a99a288ac77e
#                              435bd20/executions/ba93fee5474d2e343a10a1c4b6e96bcada7c66a6/data/steps_ou
#                              tputs'
#                     INFO     ['distilabel.pipeline'] ⌛ The steps of the pipeline will be loaded in    ]8;id=97096;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=778306;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1046\1046]8;;\
#                              stages:
#                               * Legend: 🚰 GeneratorStep 🌐 GlobalStep 🔄 Step
#                               * Stage 0:
#                                 - 🚰 'load_data_from_dicts_0'
#                                 - 🔄 'text_generation_0'
#                                 - 🔄 'text_generation_1'
#                     INFO     ['distilabel.pipeline'] ⏳ Waiting for all the steps of stage 0 to        ]8;id=899499;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=372388;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1382\1382]8;;\
#                              load...
# Device set to use cuda:0
# Device set to use cuda:0
# Device set to use cuda:0
# [08/27/25 20:25:02] INFO     ['distilabel.pipeline'] ⏳ Steps from stage 0 loaded: 1/3                 ]8;id=204654;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=17810;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1418\1418]8;;\
#                               * 'load_data_from_dicts_0' replicas: 1/1
#                               * 'text_generation_0' replicas: 0/1
#                               * 'text_generation_1' replicas: 0/1
# [08/27/25 20:25:04] INFO     ['distilabel.pipeline'] ⏳ Steps from stage 0 loaded: 3/3                 ]8;id=555088;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=897276;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1418\1418]8;;\
#                               * 'load_data_from_dicts_0' replicas: 1/1
#                               * 'text_generation_0' replicas: 1/1
#                               * 'text_generation_1' replicas: 1/1
#                     INFO     ['distilabel.pipeline'] ✅ All the steps from stage 0 have been loaded!   ]8;id=822695;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=119394;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1422\1422]8;;\
#                     INFO     ['distilabel.step.load_data_from_dicts_0'] 🚰 Starting yielding    ]8;id=344774;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=116095;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/step_wrapper.py#179\179]8;;\
#                              batches from generator step 'load_data_from_dicts_0'. Offset: 0
#                     INFO     ['distilabel.step.load_data_from_dicts_0'] 📨 Step                 ]8;id=812359;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=287421;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/step_wrapper.py#290\290]8;;\
#                              'load_data_from_dicts_0' sending batch 0 to output queue
#                     INFO     ['distilabel.step.load_data_from_dicts_0'] 🏁 Finished running     ]8;id=269110;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=470802;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/step_wrapper.py#129\129]8;;\
#                              step 'load_data_from_dicts_0' (replica ID: 0)
#                     INFO     ['distilabel.step.text_generation_0'] 📦 Processing batch 0 in     ]8;id=69279;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=634120;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/step_wrapper.py#230\230]8;;\
#                              'text_generation_0' (replica ID: 0)
# [08/27/25 20:24:59] INFO     ['distilabel.pipeline'] 📝 Pipeline data will be written to               ]8;id=145122;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=410755;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1015\1015]8;;\
#                              '/home/ai-makina/.cache/distilabel/pipelines/pipeline_load_data_from_dict
#                              s_0_text_generation_0_text_generation_1/c01ebfb0c402b5259a883a99a288ac77e
#                              435bd20/executions/ba93fee5474d2e343a10a1c4b6e96bcada7c66a6/data/steps_ou
#                              tputs'
#                     INFO     ['distilabel.pipeline'] ⌛ The steps of the pipeline will be loaded in    ]8;id=97096;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=778306;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1046\1046]8;;\
#                              stages:
#                               * Legend: 🚰 GeneratorStep 🌐 GlobalStep 🔄 Step
#                               * Stage 0:
#                                 - 🚰 'load_data_from_dicts_0'
#                                 - 🔄 'text_generation_0'
#                                 - 🔄 'text_generation_1'
#                     INFO     ['distilabel.pipeline'] ⏳ Waiting for all the steps of stage 0 to        ]8;id=899499;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=372388;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1382\1382]8;;\
#                              load...
# Device set to use cuda:0
# Device set to use cuda:0
# Device set to use cuda:0
# [08/27/25 20:25:02] INFO     ['distilabel.pipeline'] ⏳ Steps from stage 0 loaded: 1/3                 ]8;id=204654;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=17810;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1418\1418]8;;\
#                               * 'load_data_from_dicts_0' replicas: 1/1
#                               * 'text_generation_0' replicas: 0/1
#                               * 'text_generation_1' replicas: 0/1
# [08/27/25 20:25:04] INFO     ['distilabel.pipeline'] ⏳ Steps from stage 0 loaded: 3/3                 ]8;id=555088;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=897276;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1418\1418]8;;\
#                               * 'load_data_from_dicts_0' replicas: 1/1
#                               * 'text_generation_0' replicas: 1/1
#                               * 'text_generation_1' replicas: 1/1
#                     INFO     ['distilabel.pipeline'] ✅ All the steps from stage 0 have been loaded!   ]8;id=822695;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=119394;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1422\1422]8;;\
#                     INFO     ['distilabel.step.load_data_from_dicts_0'] 🚰 Starting yielding    ]8;id=344774;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=116095;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/step_wrapper.py#179\179]8;;\
#                              batches from generator step 'load_data_from_dicts_0'. Offset: 0
#                     INFO     ['distilabel.step.load_data_from_dicts_0'] 📨 Step                 ]8;id=812359;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=287421;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/step_wrapper.py#290\290]8;;\
#                              'load_data_from_dicts_0' sending batch 0 to output queue
#                     INFO     ['distilabel.step.load_data_from_dicts_0'] 🏁 Finished running     ]8;id=269110;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=470802;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/step_wrapper.py#129\129]8;;\
#                              step 'load_data_from_dicts_0' (replica ID: 0)
#                     INFO     ['distilabel.step.text_generation_0'] 📦 Processing batch 0 in     ]8;id=69279;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=634120;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/step_wrapper.py#230\230]8;;\
#                              'text_generation_0' (replica ID: 0)
# [08/27/25 20:25:05] INFO     ['distilabel.step.text_generation_0'] 📨 Step 'text_generation_0'  ]8;id=788685;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=490125;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/step_wrapper.py#290\290]8;;\
#                              sending batch 0 to output queue
# [08/27/25 20:24:59] INFO     ['distilabel.pipeline'] 📝 Pipeline data will be written to               ]8;id=145122;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=410755;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1015\1015]8;;\
#                              '/home/ai-makina/.cache/distilabel/pipelines/pipeline_load_data_from_dict
#                              s_0_text_generation_0_text_generation_1/c01ebfb0c402b5259a883a99a288ac77e
#                              435bd20/executions/ba93fee5474d2e343a10a1c4b6e96bcada7c66a6/data/steps_ou
#                              tputs'
#                     INFO     ['distilabel.pipeline'] ⌛ The steps of the pipeline will be loaded in    ]8;id=97096;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=778306;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1046\1046]8;;\
#                              stages:
#                               * Legend: 🚰 GeneratorStep 🌐 GlobalStep 🔄 Step
#                               * Stage 0:
#                                 - 🚰 'load_data_from_dicts_0'
#                                 - 🔄 'text_generation_0'
#                                 - 🔄 'text_generation_1'
#                     INFO     ['distilabel.pipeline'] ⏳ Waiting for all the steps of stage 0 to        ]8;id=899499;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=372388;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1382\1382]8;;\
#                              load...
# Device set to use cuda:0
# Device set to use cuda:0
# Device set to use cuda:0
# [08/27/25 20:25:02] INFO     ['distilabel.pipeline'] ⏳ Steps from stage 0 loaded: 1/3                 ]8;id=204654;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=17810;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1418\1418]8;;\
#                               * 'load_data_from_dicts_0' replicas: 1/1
#                               * 'text_generation_0' replicas: 0/1
#                               * 'text_generation_1' replicas: 0/1
# [08/27/25 20:25:04] INFO     ['distilabel.pipeline'] ⏳ Steps from stage 0 loaded: 3/3                 ]8;id=555088;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=897276;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1418\1418]8;;\
#                               * 'load_data_from_dicts_0' replicas: 1/1
#                               * 'text_generation_0' replicas: 1/1
#                               * 'text_generation_1' replicas: 1/1
#                     INFO     ['distilabel.pipeline'] ✅ All the steps from stage 0 have been loaded!   ]8;id=822695;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=119394;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1422\1422]8;;\
#                     INFO     ['distilabel.step.load_data_from_dicts_0'] 🚰 Starting yielding    ]8;id=344774;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=116095;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/step_wrapper.py#179\179]8;;\
#                              batches from generator step 'load_data_from_dicts_0'. Offset: 0
#                     INFO     ['distilabel.step.load_data_from_dicts_0'] 📨 Step                 ]8;id=812359;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=287421;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/step_wrapper.py#290\290]8;;\
#                              'load_data_from_dicts_0' sending batch 0 to output queue
#                     INFO     ['distilabel.step.load_data_from_dicts_0'] 🏁 Finished running     ]8;id=269110;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=470802;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/step_wrapper.py#129\129]8;;\
#                              step 'load_data_from_dicts_0' (replica ID: 0)
#                     INFO     ['distilabel.step.text_generation_0'] 📦 Processing batch 0 in     ]8;id=69279;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=634120;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/step_wrapper.py#230\230]8;;\
#                              'text_generation_0' (replica ID: 0)
# [08/27/25 20:25:05] INFO     ['distilabel.step.text_generation_0'] 📨 Step 'text_generation_0'  ]8;id=788685;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=490125;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/step_wrapper.py#290\290]8;;\
#                              sending batch 0 to output queue
#                     INFO     ['distilabel.step.text_generation_0'] 🏁 Finished running step     ]8;id=786195;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=986205;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/step_wrapper.py#129\129]8;;\
#                              'text_generation_0' (replica ID: 0)
#                     INFO     ['distilabel.step.text_generation_1'] 📦 Processing batch 0 in     ]8;id=801532;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=227900;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/step_wrapper.py#230\230]8;;\
#                              'text_generation_1' (replica ID: 0)
# [08/27/25 20:24:59] INFO     ['distilabel.pipeline'] 📝 Pipeline data will be written to               ]8;id=145122;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=410755;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1015\1015]8;;\
#                              '/home/ai-makina/.cache/distilabel/pipelines/pipeline_load_data_from_dict
#                              s_0_text_generation_0_text_generation_1/c01ebfb0c402b5259a883a99a288ac77e
#                              435bd20/executions/ba93fee5474d2e343a10a1c4b6e96bcada7c66a6/data/steps_ou
#                              tputs'
#                     INFO     ['distilabel.pipeline'] ⌛ The steps of the pipeline will be loaded in    ]8;id=97096;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=778306;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1046\1046]8;;\
#                              stages:
#                               * Legend: 🚰 GeneratorStep 🌐 GlobalStep 🔄 Step
#                               * Stage 0:
#                                 - 🚰 'load_data_from_dicts_0'
#                                 - 🔄 'text_generation_0'
#                                 - 🔄 'text_generation_1'
#                     INFO     ['distilabel.pipeline'] ⏳ Waiting for all the steps of stage 0 to        ]8;id=899499;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=372388;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1382\1382]8;;\
#                              load...
# Device set to use cuda:0
# Device set to use cuda:0
# Device set to use cuda:0
# [08/27/25 20:25:02] INFO     ['distilabel.pipeline'] ⏳ Steps from stage 0 loaded: 1/3                 ]8;id=204654;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=17810;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1418\1418]8;;\
#                               * 'load_data_from_dicts_0' replicas: 1/1
#                               * 'text_generation_0' replicas: 0/1
#                               * 'text_generation_1' replicas: 0/1
# [08/27/25 20:25:04] INFO     ['distilabel.pipeline'] ⏳ Steps from stage 0 loaded: 3/3                 ]8;id=555088;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=897276;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1418\1418]8;;\
#                               * 'load_data_from_dicts_0' replicas: 1/1
#                               * 'text_generation_0' replicas: 1/1
#                               * 'text_generation_1' replicas: 1/1
#                     INFO     ['distilabel.pipeline'] ✅ All the steps from stage 0 have been loaded!   ]8;id=822695;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=119394;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/base.py#1422\1422]8;;\
#                     INFO     ['distilabel.step.load_data_from_dicts_0'] 🚰 Starting yielding    ]8;id=344774;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=116095;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/step_wrapper.py#179\179]8;;\
#                              batches from generator step 'load_data_from_dicts_0'. Offset: 0
#                     INFO     ['distilabel.step.load_data_from_dicts_0'] 📨 Step                 ]8;id=812359;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=287421;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/step_wrapper.py#290\290]8;;\
#                              'load_data_from_dicts_0' sending batch 0 to output queue
#                     INFO     ['distilabel.step.load_data_from_dicts_0'] 🏁 Finished running     ]8;id=269110;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=470802;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/step_wrapper.py#129\129]8;;\
#                              step 'load_data_from_dicts_0' (replica ID: 0)
#                     INFO     ['distilabel.step.text_generation_0'] 📦 Processing batch 0 in     ]8;id=69279;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=634120;file:///home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/distilabel/pipeline/step_wrapper.py#230\230]8;;\
#                              'text_generation_0' (replica ID: 0)
# ...
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                  │
# │ /home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/huggingface_hub/utils │
# │ /_validators.py:114 in _inner_fn                                                                 │
# │                                                                                                  │
# │   111 │   │   if check_use_auth_token:                                                           │
# │   112 │   │   │   kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=ha   │
# │   113 │   │                                                                                      │
# │ ❱ 114 │   │   return fn(*args, **kwargs)                                                         │
# │   115 │                                                                                          │
# │   116 │   return _inner_fn  # type: ignore                                                       │
# │   117                                                                                            │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │             arg_name = 'endpoint'                                                            │ │
# │ │            arg_value = None                                                                  │ │
# │ │                 args = ()                                                                    │ │
# │ │ check_use_auth_token = True                                                                  │ │
# │ │            has_token = True                                                                  │ │
# │ │               kwargs = {                                                                     │ │
# │ │                        │   'url':                                                            │ │
# │ │                        'https://huggingface.co/datasets/huggingface-smol-course-instruction… │ │
# │ │                        │   'proxies': None,                                                  │ │
# │ │                        │   'timeout': 10,                                                    │ │
# │ │                        │   'headers': {                                                      │ │
# │ │                        │   │   'user-agent': 'unknown/None; hf_hub/0.34.3; python/3.10.12;   │ │
# │ │                        torch/2.7.1',                                                         │ │
# │ │                        │   │   'authorization': 'Bearer                                      │ │
# │ │                        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'                                │ │
# │ │                        │   },                                                                │ │
# │ │                        │   'token': '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',                 │ │
# │ │                        │   'endpoint': None                                                  │ │
# │ │                        }                                                                     │ │
# │ │            signature = <Signature (url: str, token: Union[bool, str, NoneType] = None,       │ │
# │ │                        proxies: Optional[Dict] = None, timeout: Optional[float] = 10,        │ │
# │ │                        library_name: Optional[str] = None, library_version: Optional[str] =  │ │
# │ │                        None, user_agent: Union[Dict, str, NoneType] = None, headers:         │ │
# │ │                        Optional[Dict[str, str]] = None, endpoint: Optional[str] = None) ->   │ │
# │ │                        huggingface_hub.file_download.HfFileMetadata>                         │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                  │
# │ /home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/huggingface_hub/file_ │
# │ download.py:1463 in get_hf_file_metadata                                                         │
# │                                                                                                  │
# │   1460 │   hf_headers["Accept-Encoding"] = "identity"  # prevent any compression => we want to   │
# │   1461 │                                                                                         │
# │   1462 │   # Retrieve metadata                                                                   │
# │ ❱ 1463 │   r = _request_wrapper(                                                                 │
# │   1464 │   │   method="HEAD",                                                                    │
# │   1465 │   │   url=url,                                                                          │
# │   1466 │   │   headers=hf_headers,                                                               │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │        endpoint = None                                                                       │ │
# │ │         headers = {                                                                          │ │
# │ │                   │   'user-agent': 'unknown/None; hf_hub/0.34.3; python/3.10.12;            │ │
# │ │                   torch/2.7.1',                                                              │ │
# │ │                   │   'authorization': 'Bearer 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'        │ │
# │ │                   }                                                                          │ │
# │ │      hf_headers = {                                                                          │ │
# │ │                   │   'user-agent': 'unknown/None; hf_hub/0.34.3; python/3.10.12;            │ │
# │ │                   torch/2.7.1',                                                              │ │
# │ │                   │   'authorization': 'Bearer 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',       │ │
# │ │                   │   'Accept-Encoding': 'identity'                                          │ │
# │ │                   }                                                                          │ │
# │ │    library_name = None                                                                       │ │
# │ │ library_version = None                                                                       │ │
# │ │         proxies = None                                                                       │ │
# │ │         timeout = 10                                                                         │ │
# │ │           token = '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'                                    │ │
# │ │             url = 'https://huggingface.co/datasets/huggingface-smol-course-instruction-tuni… │ │
# │ │      user_agent = None                                                                       │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                  │
# │ /home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/huggingface_hub/file_ │
# │ download.py:286 in _request_wrapper                                                              │
# │                                                                                                  │
# │    283 │   """                                                                                   │
# │    284 │   # Recursively follow relative redirects                                               │
# │    285 │   if follow_relative_redirects:                                                         │
# │ ❱  286 │   │   response = _request_wrapper(                                                      │
# │    287 │   │   │   method=method,                                                                │
# │    288 │   │   │   url=url,                                                                      │
# │    289 │   │   │   follow_relative_redirects=False,                                              │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │ follow_relative_redirects = True                                                             │ │
# │ │                    method = 'HEAD'                                                           │ │
# │ │                    params = {                                                                │ │
# │ │                             │   'headers': {                                                 │ │
# │ │                             │   │   'user-agent': 'unknown/None; hf_hub/0.34.3;              │ │
# │ │                             python/3.10.12; torch/2.7.1',                                    │ │
# │ │                             │   │   'authorization': 'Bearer                                 │ │
# │ │                             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',                          │ │
# │ │                             │   │   'Accept-Encoding': 'identity'                            │ │
# │ │                             │   },                                                           │ │
# │ │                             │   'allow_redirects': False,                                    │ │
# │ │                             │   'proxies': None,                                             │ │
# │ │                             │   'timeout': 10                                                │ │
# │ │                             }                                                                │ │
# │ │                       url = 'https://huggingface.co/datasets/huggingface-smol-course-instru… │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                  │
# │ /home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/huggingface_hub/file_ │
# │ download.py:310 in _request_wrapper                                                              │
# │                                                                                                  │
# │    307 │                                                                                         │
# │    308 │   # Perform request and return if status_code is not in the retry list.                 │
# │    309 │   response = http_backoff(method=method, url=url, **params, retry_on_exceptions=(), re  │
# │ ❱  310 │   hf_raise_for_status(response)                                                         │
# │    311 │   return response                                                                       │
# │    312                                                                                           │
# │    313                                                                                           │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │ follow_relative_redirects = False                                                            │ │
# │ │                    method = 'HEAD'                                                           │ │
# │ │                    params = {                                                                │ │
# │ │                             │   'headers': {                                                 │ │
# │ │                             │   │   'user-agent': 'unknown/None; hf_hub/0.34.3;              │ │
# │ │                             python/3.10.12; torch/2.7.1',                                    │ │
# │ │                             │   │   'authorization': 'Bearer                                 │ │
# │ │                             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',                          │ │
# │ │                             │   │   'Accept-Encoding': 'identity'                            │ │
# │ │                             │   },                                                           │ │
# │ │                             │   'allow_redirects': False,                                    │ │
# │ │                             │   'proxies': None,                                             │ │
# │ │                             │   'timeout': 10                                                │ │
# │ │                             }                                                                │ │
# │ │                  response = <Response [404]>                                                 │ │
# │ │                       url = 'https://huggingface.co/datasets/huggingface-smol-course-instru… │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                  │
# │ /home/ai-makina/.pyenv/versions/smol-course-2/lib/python3.10/site-packages/huggingface_hub/utils │
# │ /_http.py:459 in hf_raise_for_status                                                             │
# │                                                                                                  │
# │   456 │   │   │   │   " make sure you are authenticated. For more details, see"                  │
# │   457 │   │   │   │   " https://huggingface.co/docs/huggingface_hub/authentication"              │
# │   458 │   │   │   )                                                                              │
# │ ❱ 459 │   │   │   raise _format(RepositoryNotFoundError, message, response) from e               │
# │   460 │   │                                                                                      │
# │   461 │   │   elif response.status_code == 400:                                                  │
# │   462 │   │   │   message = (                                                                    │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │ endpoint_name = None                                                                         │ │
# │ │    error_code = 'RepoNotFound'                                                               │ │
# │ │ error_message = 'Repository not found'                                                       │ │
# │ │       message = '404 Client Error.\n\nRepository Not Found for url:                          │ │
# │ │                 https://huggingface.co/datasets'+312                                         │ │
# │ │      response = <Response [404]>                                                             │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# RepositoryNotFoundError: 404 Client Error. (Request ID:
# Root=1-68afcc16-0376e03655041f4b64df8dd2;c8056ba3-863d-48a4-b584-66c369293466)
#
# Repository Not Found for url:
# https://huggingface.co/datasets/huggingface-smol-course-instruction-tuning-dataset/resolve/main/README.md.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated. For more details, see
# https://huggingface.co/docs/huggingface_hub/authentication

# %% [markdown]
# ## 🌯 That's a wrap
#
# You've now seen how to generate a dataset for instruction tuning. You could use this to:
#
# - Generate a dataset for instruction tuning.
# - Create evaluation datasets for instruction tuning.
#
# Next
#
# 🧑‍🏫 Learn - About [generating preference datasets](./preference_datasets.md)
# 🏋️‍♂️ Fine-tune a model for instruction tuning with a synthetic dataset based on the [instruction tuning chapter](../../1_instruction_tuning/README.md)
